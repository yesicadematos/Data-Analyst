# %%
import sqlalchemy as sa
import urllib 
import pandas as pd 
import psycopg2

# %%
parametros = (
    'DRIVER=psycopg2;'
    'SERVER=localhost;'
    'DATABASE=challenge_data_analyst;'
    'UID=postgres;'
    'PWD=ADMIN1234;')

# %%
coneccion = sa.create_engine("postgresql://postgres:ADMIN1234@localhost:5432/challenge_data_analyst")
engine = sa.create_engine ("postgresql+psycopg2://{}".format(parametros))
params = urllib.parse.quote_plus(parametros)
engine23 = sa.create_engine('postgresql+psycopg2://odbc_connect{}'.format(params))

# %%
data = pd.read_csv("./biblioteca.csv")
df = pd.DataFrame(data)
df.sample(5)
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observacion  \
# 842    6455030            6            6455          NaN
# 1086   6427010            6            6427          NaN
# 1703  66126060           66           66126          NaN
# 1133  22119010           22           22119          NaN
# 364    6455030            6            6455          NaN
#
#                  CategorÃ­a  Subcategoria     Provincia  \
# 842   Bibliotecas Populares           NaN  Buenos Aires
# 1086  Bibliotecas Populares           NaN  Buenos Aires
# 1703  Bibliotecas Populares           NaN         Salta
# 1133  Bibliotecas Populares           NaN         Chaco
# 364   Bibliotecas Populares           NaN  Buenos Aires
#
#                  Departamento                Localidad  \
# 842                Las Flores               Las Flores
# 1086               La Matanza          Isidro Casanova
# 1703                     Oran                 Pichanal
# 1133  Presidencia de la Plaza  Presidencia de la Plaza
# 364                Las Flores               Las Flores
#
#                                                  Nombre  ...  \
# 842          Biblioteca Popular Dr. Pablo A. Minellondo  ...
# 1086             Biblioteca Popular Delia C. de Armagno  ...
# 1703           Biblioteca Popular Rosa Gareca de Moreno  ...
# 1133  AsociaciÃ³n Amigos Biblioteca Popular PÃºblica...  ...
# 364                       Biblioteca Popular 25 de Mayo  ...
#
#                                      Mail  Web InformaciÃ³n adicional  \
# 842   dirrecioncultura@52.coopenet.com.ar  NaN                    NaN
# 1086           colepizzurno@ciudad.com.ar  NaN                    NaN
# 1703                                  s/d  NaN                    NaN
# 1133    bib_pop_estrada_plaza@hotmail.com  NaN                    NaN
# 364                info@bp25demayo.org.ar  NaN                    NaN
#
#         Latitud   Longitud    TipoLatitudLongitud   Fuente  Tipo_gestion  \
# 842  -36.014833 -59.099633  LocalizaciÃ³n precisa  CONABIP   Comunitaria
# 1086 -34.712583 -58.591183  LocalizaciÃ³n precisa  CONABIP   Comunitaria
# 1703 -23.324967 -64.220183  LocalizaciÃ³n precisa  CONABIP   Comunitaria
# 1133 -27.001741 -59.843952  LocalizaciÃ³n precisa  CONABIP   Comunitaria
# 364  -36.012783 -59.099100  LocalizaciÃ³n precisa  CONABIP   Comunitaria
#
#       aÃ±o_inicio  AÃ±o_actualizacion
# 842        1972.0                2018
# 1086       1930.0                2018
# 1703       1930.0                2018
# 1133       1967.0                2018
# 364        1928.0                2018
#
# [5 rows x 25 columns]

# %%
from sqlalchemy import create_engine
engine23= create_engine('postgresql://postgres:ADMIN1234@localhost:5432/challenge_data_analyst')
# engine23 = create_engine('postgresql+psycopg2://postgres:admin1234/@localhost/challenge_data_analyst')

# %%
engine23.connect('SELECT *FROM biblioteca;')
df.to_sql("biblioteca",con=coneccion,if_exists='append',index=False)
# Out:
# 17
