# %%
import sqlalchemy as sa
import urllib 
import pandas as pd 
import psycopg2

# %%
parametros = ('SERVER=LOCALHOST;'
    'DATABASE=challenge_data_analyst;'
    'UID=postgres;'
    'PWD=admin1234;'
            )

# %%
# coneccion = sa.create_engine("postgresql://postgres:admin1234@localhost/PROYECTO")
# engine = sa.create_engine ("postgresql+psycopg2://{}".format(parametros))
engine = sa.create_engine ('postgresql+psycopg2://postgres:admin1234@localhost/challenge_data_analyst')

# %%
data = pd.read_csv("./biblioteca.csv")
df = pd.DataFrame(data)
# df.sample(5)

# %%
df.to_sql("prueba_carga",con=engine23,if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Yesica\documents\challenge_data_analyst\venv\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File c:\Users\Yesica\documents\challenge_data_analyst\venv\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Yesica\documents\challenge_data_analyst\venv\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
# ...

# %%
from sqlalchemy import create_engine

engine23 = create_engine('postgresql+psycopg2://postgres:admin1234\
@localhost/challenge_data_analyst')
