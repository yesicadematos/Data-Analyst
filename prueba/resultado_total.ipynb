# %%
import sqlalchemy as sa
import pandas as pd 
from sqlalchemy import text
from conector import enginesexy

# %% [markdown]
# leemos los archivis de la base de datos para hacer algunas consultas

# %%
df_total=pd.read_sql
text=("""SELECT "Provincia" ,COUNT ('Pantallas') AS total_pantallas
FROM "CINES","Provincia"
GROUP BY "Provincia";""")
muestreo1 = pd.DataFrame(enginesexy.execute(text))
muestreo1.head(24)
# Out:
#                            Provincia  total_pantallas
# 0                           Santa Fe              329
# 1                           La Pampa              329
# 2                            Formosa              329
# 3                           TucumÃ¡n              329
# 4                           San Luis              329
# 5                        Entre RÃ­os              329
# 6                            Mendoza              329
# 7                              Salta              329
# 8                         Santa Cruz              329
# 9                          Catamarca              329
# 10                        RÃ­o Negro              329
# 11                          NeuquÃ©n              329
# 12                             Jujuy              329
# 13               Santiago del Estero              329
# 14                          San Juan              329
# 15                          Misiones              329
# ...

# %%
df_total2=pd.read_sql
text=("""SELECT "IdProvincia", COUNT ('Categiria') AS Total_por_Categoria
FROM "CINES","BIBLIOTECA","MUSEOS","Provincia"
GROUP BY "IdProvincia";""")
muestreo1 = pd.DataFrame(enginesexy.execute(text))
muestreo1.head()

# %%
"BIBLIOTECA","MUSEOS"

# %%
# df_totalC.groupby(['Cod_Loc'])[['Id']].count()

# %%
df_totalC
# Out:
#        Id   Cod_Loc      Categoria                           Nombre  \
# 0      0C  10049030  Salas de cine                     Cinemacenter
# 1      1C  10091150  Salas de cine     Centro Cultural San AgustÃ­n
# 2      2C  22140060  Salas de cine            Los Cines De La Costa
# 3      3C  26091020  Salas de cine        Deborah Jones De Williams
# 4      4C  18007010  Salas de cine                         Fantasio
# ..    ...       ...            ...                              ...
# 324  324C   6455030  Salas de cine                  Cine San Martin
# 325  325C   6434010  Salas de cine           Zona Cines Coto LanÃºs
# 326  326C   6791050  Salas de cine             Espacio INCAA Unicen
# 327  327C  10049030  Salas de cine            Cine Teatro Catamarca
# 328  328C   6427010  Salas de cine  Espacio INCAA Km 16 La Matanza
#
#                                  Direccion Piso Observacion  \
# 0            Intendente Mamerto Medina 220  s/d        None
# ...

# %%
df_totalM=pd.read_sql("""SELECT * FROM "MUSEOS" """,
con=enginesexy)

# %%
df_totalM.sample(4)
# Out:
#          Id   Cod_Loc                                             Nombre  \
# 680    680M  42021020  Museo Policial Crio General Alberto Dionisio A...
# 1137  1137M  86147130                 Museo Municipal RincÃ³n De Atacama
# 836    835M  58112040  Museo Provincial De Ciencias Naturales Prof. D...
# 239    239M  26007020                                        Museo Gemas
#
#                                 Categoria subcategoria  \
# 680   Espacios de ExhibiciÃ³n Patrimonial       Museos
# 1137  Espacios de ExhibiciÃ³n Patrimonial       Museos
# 836   Espacios de ExhibiciÃ³n Patrimonial       Museos
# 239   Espacios de ExhibiciÃ³n Patrimonial       Museos
#
#                                           Direccion Observacion  Piso   Web  \
# 680                        Avda. Belgrano Norte 140        None  None  None
# 1137                                    Caseros 468        None  None  None
# 836   MartÃ­n Cirilo Etcheluz y EjÃ©rcito Argentino        None  None  None
# ...

# %%
# engineok = sa.create_engine('postgresql://postgres:ADMIN1234@localhost:5432/challenge_data_analyst')

# text=("""ALTER TABLE  "BIBLIOTECA"
# ADD FOREIGN KEY ( "Cod_Loc")  REFERENCES "Localidad" ( "Cod_Loc") ;""")
engineok.execute(text)

# %%
df_totalC=pd.read_sql("""SELECT * FROM "CINES" """,
con=enginesexy)

# %%
df_totalC.columns
# Out:
# Index(['Id', 'Cod_Loc', 'Categoria', 'Nombre', 'Direccion', 'Piso',
#        'Observacion', 'Informacion Adicional', 'Telefono', 'Mail', 'Web',
#        'Latitud', 'Longitud', 'TipoLatitudLongitud', 'Fuente', 'Tipo_gestion',
#        'Pantallas', 'Butacas', 'Espacio_Incaa', 'Ano_Actualizacion'],
#       dtype='object')

# %%
df_totalB=pd.read_sql("""SELECT * FROM "BIBLIOTECA" """,
con=enginesexy)

# %%
df_totalB
# Out:
#        Cod_Loc Observacion              Categoria Subcategoria  \
# 0     70049060        None  Bibliotecas Populares         None
# 1      2000010        None  Bibliotecas Populares         None
# 2      2000010        None  Bibliotecas Populares         None
# 3      2000010        None  Bibliotecas Populares         None
# 4      2000010        None  Bibliotecas Populares         None
# ...        ...         ...                    ...          ...
# 2012  62042560        None  Bibliotecas Populares         None
# 2013  70028010        None  Bibliotecas Populares         None
# 2014  62007080        None  Bibliotecas Populares         None
# 2015  62077010        None  Bibliotecas Populares         None
# 2016  62042360        None  Bibliotecas Populares         None
#
#                                            Nombre             Domicilio  Piso  \
# 0            Biblioteca Popular Juan P. Garramuno         Santo Domingo  None
# ...

# %% [markdown]
# con .append hacemos la union para que queden 1 solo conjunto de informacion

# %%
df_total_parcial=df_totalB.append(df_totalC ,sort=False,ignore_index=False)
# .append(df_totalM  , ignore_index=False)
# Out:
# C:\Users\Yesica\AppData\Local\Temp\ipykernel_19656\690628074.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total_parcial=df_totalB.append(df_totalC ,sort=False,ignore_index=False)

# %%
df_total2=df_totalC.append(df_totalM  , ignore_index=False)
# Out:
# C:\Users\Yesica\AppData\Local\Temp\ipykernel_19656\1020063892.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total2=df_totalC.append(df_totalM  , ignore_index=False)

# %%
df_total_parcial.head(2)
# Out:
#     Cod_Loc Observacion              Categoria Subcategoria  \
# 0  70049060        None  Bibliotecas Populares         None
# 1   2000010        None  Bibliotecas Populares         None
#
#                                         Nombre      Domicilio  Piso  Telefono  \
# 0         Biblioteca Popular Juan P. Garramuno  Santo Domingo  None       s/d
# 1  Biblioteca Popular Helena Larroque de Roffo  SimbrÃ³n 3058  None  45010078
#
#                            Mail   Web Informacion Adicional    Latitud  \
# 0                           s/d  None                  None -30.209250
# 1  asociacionroffo@yahoo.com.ar  None                  None -34.598461
#
#     Longitud    TipoLatitudLongitud   Fuente Tipo_gestion  Ano_Inicio  \
# 0 -69.130117  LocalizaciÃ³n precisa  CONABIP  Comunitaria      1930.0
# 1 -58.494690  LocalizaciÃ³n precisa  CONABIP  Comunitaria      1916.0
#
#    Ano_Actualizacion  Id
# 0               2018  0B
# 1               2018  1B

# %%
df_total = df_total_parcial.append(df_totalM, sort=False,ignore_index=False)
df_total.tail()
# Out:
# C:\Users\Yesica\AppData\Local\Temp\ipykernel_19656\212762180.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total_parcial.append(df_totalM, sort=False,ignore_index=False)
#        Cod_Loc Observacion                            Categoria Subcategoria  \
# 1177  90098040        None  Espacios de ExhibiciÃ³n Patrimonial          NaN
# 1178  90105080        None  Espacios de ExhibiciÃ³n Patrimonial          NaN
# 1179  90105080        None  Espacios de ExhibiciÃ³n Patrimonial          NaN
# 1180  90105070        None  Espacios de ExhibiciÃ³n Patrimonial          NaN
# 1181  90098040        None  Espacios de ExhibiciÃ³n Patrimonial          NaN
#
#                                                  Nombre Domicilio  Piso  \
# 1177  Museo HistÃ³rico Y ArqueolÃ³gico JesuÃ­tico La...       NaN  None
# 1178                Mac-Museo ArqueolÃ³gico El Cadillal       NaN  None
# ...

# %% [markdown]
# con los datos en conjunto podemos ver el registro total por 'Categoria' y 'Fuente' utilizando Groupby

# %%
df_total.groupby(['Fuente','Categoria'])[['Id']].count()
# Out:
#                                                                                           Id
# Fuente                                             Categoria
# CNMLH - Enlace SInCA                               Espacios de ExhibiciÃ³n Patrimonial     1
# CNMLH - Ente Cultural de TucumÃ¡n                  Espacios de ExhibiciÃ³n Patrimonial     1
# CONABIP                                            Bibliotecas Populares                4020
# DNPyM                                              Espacios de ExhibiciÃ³n Patrimonial  1048
# DirecciÃ³n Provincial de Patrimonio Cultural - ... Espacios de ExhibiciÃ³n Patrimonial     1
# DirecciÃ³n de Cultura de Villa Allende             Espacios de ExhibiciÃ³n Patrimonial     2
# DirecciÃ³n de Cultura y de EducaciÃ³n de la Mun... Espacios de ExhibiciÃ³n Patrimonial     1
# Gob. Pcia.                                         Bibliotecas Populares                   2
# ...

# %% [markdown]
# con el mismo conjunto de datos podemos ver los registros totales pero esta ves por 'Provincia' y 'Categoria', pero ahora utilizamos .Concat y optenemos los mismos resultados.

# %%
df_resultado=pd.concat([df_totalC,df_totalB,df_totalM], sort=False, ignore_index=False)
df_resultado.sample(6)
# Out:
#        Cod_Loc Observacion                            Categoria Subcategoria  \
# 378    2000010        None  Espacios de ExhibiciÃ³n Patrimonial          NaN
# 799    6427010        None                Bibliotecas Populares         None
# 1362  82021010        None                Bibliotecas Populares         None
# 1040  50091020        None                Bibliotecas Populares         None
# 1378  10098030        None                Bibliotecas Populares         None
# 1034  70084010        None                Bibliotecas Populares         None
#
#                                                  Nombre  \
# 378                            Museo Notarial Argentino
# 799                 Biblioteca Popular Alfonsina Storni
# 1362  Biblioteca PÃºblica Com.y Popular BartolomÃ© M...
# 1040                  Biblioteca Popular Mariano Moreno
# 1378              Biblioteca Popular Santa Rosa de Lima
# 1034             Biblioteca Popular Miguel Beato Tejada
#
# ...

# %%
df_resultado.groupby(['IdProvincia','Categoria']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Yesica\Documents\challenge_data_analyst\prueba\resultado_total.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yesica/Documents/challenge_data_analyst/prueba/resultado_total.ipynb#ch0000018?line=0'>1</a> df_resultado.groupby(['IdProvincia','Categoria']).count()
#
# File c:\Users\Yesica\documents\challenge_data_analyst\venv\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
# ...

# %%
df_totalP=pd.read_sql("""SELECT * FROM "Provincia" """,
con=enginesexy)

# %%
df_totalP
# Out:
#     IdProvincia                         Provincia
# 0            70                          San Juan
# 1             2  Ciudad AutÃ³noma de Buenos Aires
# 2             6                      Buenos Aires
# 3            30                       Entre RÃ­os
# 4            82                          Santa Fe
# 5            18                        Corrientes
# 6            14                          CÃ³rdoba
# 7            74                          San Luis
# 8            86               Santiago del Estero
# 9            90                          TucumÃ¡n
# 10           50                           Mendoza
# 11           46                          La Rioja
# 12           10                         Catamarca
# 13           66                             Salta
# 14           38                             Jujuy
# 15           22                             Chaco
# 16           34                           Formosa
# 17           54                          Misiones
# ...

# %%
df_total2=pd.concat([df_totalC , df_totalP] , ignore_index=True, sort=False)
df_total2.sample(3)
# Out:
#          Cod_Loc Observacion              Categoria Subcategoria  \
# 1970  90112030.0        None  Bibliotecas Populares         None
# 893   82042130.0        None  Bibliotecas Populares         None
# 1982  26007020.0        None  Bibliotecas Populares         None
#
#                                      Nombre  \
# 1970      Biblioteca Popular Mariano Moreno
# 893       Biblioteca Popular Mariano Moreno
# 1982  Biblioteca Popular D. RaÃºl AlfonsÃ­n
#
#                                      Domicilio  Piso Telefono  \
# 1970               25 de Mayo (2Âª Cuadra) 646  None      s/d
# 893   Av.Hughes y Rivadavia-Ex-Est.Ferrocarril  None   961645
# 1982                              La Plata 893  None      s/d
#
#                                Mail   Web  ...    Latitud   Longitud  \
# 1970                            s/d  None  ... -26.232083 -65.280183
# 893   bibliohug@s11.coopenet.com.ar  None  ... -33.799200 -61.336733
# ...

# %% [markdown]
# Aca podemos ver los regitros de Cines (Pantallas , Butacas, Espacio_Incaa )

# %%
df_total2.groupby(['Pantallas', 'Butacas', 'Espacio_Incaa'])[['IdProvincia']].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Yesica\Documents\challenge_data_analyst\prueba\resultado_total.ipynb Cell 29' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yesica/Documents/challenge_data_analyst/prueba/resultado_total.ipynb#ch0000023?line=0'>1</a> df_total2.groupby(['Pantallas', 'Butacas', 'Espacio_Incaa'])[['IdProvincia']].count()
#
# File c:\Users\Yesica\documents\challenge_data_analyst\venv\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
# ...

# %% [markdown]
# **PRUEBAS ECHAS EL SABADO**

# %%
# query11 = text("""SELECT "Pantallas" "Butacas" "Espacio_Incaa"
# FROM "CINES";""")
text=("""SELECT "Pantallas", "Butacas", "Espacio_Incaa", "Provincia", "IdProvincia"
FROM "CINES", "Provincia"; """)
# query33 = text()
# text=("""SELECT "Pantallas" "Butacas" "Espacio_Incaa" "Provincia"
# FROM "CINES" "Provincia";""")

# %%
df_query = pd.read_sql(text, con=enginesexy)

# %%
df_query
# Out:
#      Pantallas Butacas Espacio_Incaa                         Provincia  \
# 0            5     743          None                          San Juan
# 1            5     743          None  Ciudad AutÃ³noma de Buenos Aires
# 2            5     743          None                      Buenos Aires
# 3            5     743          None                       Entre RÃ­os
# 4            5     743          None                          Santa Fe
# ...        ...     ...           ...                               ...
# 7891         1     390            SI                          NeuquÃ©n
# 7892         1     390            SI                        RÃ­o Negro
# 7893         1     390            SI                        Santa Cruz
# 7894         1     390            SI                  Tierra del Fuego
# 7895         1     390            SI                            Chubut
#
#       IdProvincia
# 0              70
# 1               2
# 2               6
# 3              30
# ...
